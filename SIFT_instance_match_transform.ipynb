# %% [markdown]
# # Real SIFT Feature Transform

# %% [markdown]
# ## Terminology
#
# - `zwd`: **zodiac word**, total 12 words
# - `inst`: **instance**, one data entry. In CSV, it represents a row of data
# - `feature`: contain both `kp` and `desc`, output of SIFT. one instance can have multiple features generated.
# - `kp`: **keypoint**, coming along with `desc`, the location, scale, angle of the feature.
# - `desc`: **description**, one can think of it as *visual word* or a patch of the instance, representing how the feature exactly looks like.
#
# Many code are tested/played in `play_SIFT_transform.ipynb` notebook.
#
# ## Stage 1
#
# - convert all instances into list of features (kp, desc)
# - flatten the list in to one-dim array
# - rematch each desc of each instance to the flatten list
#
# ## Stage 2
#
# - Restore back the information, each instance will count how many proportion of instances are matched for each group of zwd
#
# Here we use the better dataset `60x60addmean` for SIFT detection

# %%
from __future__ import division
import pandas as pd
import cv2
from matplotlib import pylab as pl
from matplotlib import cm
import numpy as np

# %%
# %matplotlib inline

# %%
from util.get_data import get_train_test_suite, get_new_suite

# %%
# %%time
SUITE_NAME = "60x60grey"
df_train, df_test, train_Y, train_X, test_Y, test_X = get_train_test_suite(suite_name=SUITE_NAME)
# Out:
# CPU times: user 9.65 s, sys: 330 ms, total: 9.98 s
# Wall time: 10 s

# %%
group_train = df_train.groupby("y")

# %% [markdown]
# ### Get indexes of each group

# %%
group_inst_ix = [v for v in group_train.groups.values()]

# %% [markdown]
# the grouped instance index value should be in order

# %%
# check, expect it to be y=1
# print(df_train.iloc[group_inst_ix[0][-1], 0])
for i in range(1, 13):
    assert(df_train.iloc[group_inst_ix[i - 1][-1], 0] == i)

# %%
# take y=1 鼠 and y=4 兔
part_group_inst_ix = [group_inst_ix[0], group_inst_ix[3]]

# %%
class Instance(object):
    __slots__ = ["ix", "zwd", "kp_list", "desc_list"]
    def __init__(self, ix, zwd, kp_list=None, desc_list=None):
        self.ix = ix
        self.zwd = zwd
        self.kp_list = [] if kp_list is None else kp_list
        self.desc_list = [] if desc_list is None else desc_list

# %%
# %%time
zwd_inst_mat = [[Instance(ix=ix, zwd=zwd) for ix in ix_array] for ix_array, zwd in zip(part_group_inst_ix, [1, 4])]
# Out:
# CPU times: user 2 ms, sys: 1 ms, total: 3 ms
# Wall time: 2.97 ms

# %% [markdown]
# plot

# %%
PIXEL_X = 60
PIXEL_Y = 60

# %%
# NOTE: Nest for loop are read from LEFT to RIGHT!
# np.array([ix for ix in ix_array for ix_array in part_group_inst_ix ])
# the upper will produce wrong answer
# below is the correct answer
flatten_inst_arary = np.array([inst for inst_array in zwd_inst_mat for inst in inst_array])
len(flatten_inst_arary)
# Out:
# 1040

# %%
# param. for drawing
n_subfig_x = 8
n_subfig_y = 2
px_scale = 1.2
n_subfig = n_subfig_x * n_subfig_y
f, ax_mat = pl.subplots(
    n_subfig_y, n_subfig_x, 
    figsize=(n_subfig_x * px_scale, n_subfig_y * px_scale)
)
ax_mat = ax_mat.flatten()

rand_inst_array = np.random.choice(
        flatten_inst_arary,
        size=len(ax_mat),
        replace=False
)

for inst, ax in zip(rand_inst_array, ax_mat):
    x_values = df_train.ix[inst.ix, 1:].values
    px_mat = x_values.reshape(PIXEL_X, PIXEL_Y)
    ax.imshow(px_mat, aspect=1, cmap=cm.binary)
    ax.set_adjustable('box-forced')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    ax.set_title("i: {}({})".format(inst.ix, inst.zwd))

# %% [markdown]
# ### SIFT on all instance

# %%
def grey_convert(wd_array):
    """convert [0, 1] greyscale to [0, 255] (dark, white)"""
    return np.round((1 - wd_array) * 255).astype(np.uint8)

# %% [markdown]
# Parameter for SIFT feature finding

# %%
sigma = 1.4 # default: 1.6
contrastThreshold = 0.03 # default: 0.04
nOctaveLayers = 5  # default: 3
edgeThreshold = 7 # default: 10
sift = cv2.SIFT(
    sigma=sigma, 
    contrastThreshold=contrastThreshold,
    nOctaveLayers=nOctaveLayers,
    edgeThreshold=edgeThreshold
)

# %%
# %%time
kp_bucket = []
desc_bucket = []
for inst in flatten_inst_arary:
    inst.kp_list, inst.desc_list = sift.detectAndCompute(
        grey_convert(train_X[inst.ix].reshape(PIXEL_X, PIXEL_Y)),
        None
    )
    kp_bucket.append(inst.kp_list)
    desc_bucket.append(inst.desc_list)
# Out:
# CPU times: user 5.97 s, sys: 15 ms, total: 5.99 s
# Wall time: 5.99 s

# %% [markdown]
# 有一些資料是沒有 data 的，這些 feature 轉換會失敗

# %%
no_desc_ix = [
    inst.ix for inst, desc_inst in zip(
        flatten_inst_arary, desc_bucket
    ) if desc_inst is None]
print(no_desc_ix)
# Out:
# [445]

# %%
n_subfig_x = 4; n_subfig_y = 1; px_scale = 1.2
n_subfig = n_subfig_x * n_subfig_y
f, ax_mat = pl.subplots(
    n_subfig_y, n_subfig_x, 
    figsize=(n_subfig_x * px_scale, n_subfig_y * px_scale)
)
ax_mat = ax_mat.flatten()
for ix, ax in zip(no_desc_ix, ax_mat):
    x_values = df_train.ix[ix, 1:].values
    px_mat = x_values.reshape(PIXEL_X, PIXEL_Y)
    ax.imshow(px_mat, aspect=1, cmap=cm.binary)
    ax.set_adjustable('box-forced')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    ax.set_title("i: {}".format(ix))

# %% [markdown]
# Total features

# %%
sum(len(inst.kp_list) for inst in flatten_inst_arary)
# Out:
# 49498

# %% [markdown]
# ### Draw keypoints

# %%
n_subfig_x = 6; n_subfig_y = 3; px_scale = 2.5
n_subfig = n_subfig_x * n_subfig_y
f, ax_mat = pl.subplots(
    n_subfig_y, n_subfig_x, 
    figsize=(n_subfig_x * px_scale, n_subfig_y * px_scale)
)
ax_mat = ax_mat.flatten()

rand_inst_array = np.random.choice(
    flatten_inst_arary, 
    size=n_subfig_x*n_subfig_y, replace=False)

for inst, ax in zip(rand_inst_array, ax_mat):
    x_mat = train_X[inst.ix].reshape(PIXEL_X, PIXEL_Y)
    img_sp = cv2.drawKeypoints(
        grey_convert(x_mat), 
        inst.kp_list,
        flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS
    )
    # x_values.reshape(PIXEL_X, PIXEL_Y)
    ax.imshow(img_sp, aspect=1)
    ax.set_adjustable('box-forced')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    ax.set_title("i: {}({})".format(inst.ix, inst.zwd))

# %% [markdown]
# ## Stage2 - Matching
# Here we choose the following features as output:
#
# - top K %features matched of all instances for each `zwd`
# - mean %features matched of all instances for each `zwd`
#
# So we will get `12 * (K + 1)` features in our output data frame.
#
# ### Naming
#
# ```
# z[zwd]_top[k]  :   z1_top1, z1_top2, z1_top3, ...
# z[zwd]_mean    :   z1_mean, z2_mean, ...
# ```

# %%
TOP_K = 5
N_ZODIAC = 12
out_dict = {'y': train_Y}
# Top K columns
top_column_names = [
    "z{}_top{}".format(zwd+1, k+1)
    for zwd in range(N_ZODIAC) for k in range(TOP_K)
]
# Mean columns
mean_column_names = [
    "z{}_mean".format(zwd+1) for zwd in range(N_ZODIAC)
]
out_dict.update({
    col_name : 0 for col_name in top_column_names + mean_column_names
})
df_sift_train_out = pd.DataFrame(out_dict)

# %%
# sort column name for better human readability
df_sift_train_out.columns = (
    ['y'] +
    top_column_names +
    mean_column_names
)

# %%
df_sift_train_out.columns
# Out:
# Index([u'y', u'z1_top1', u'z1_top2', u'z1_top3', u'z1_top4', u'z1_top5', u'z2_top1', u'z2_top2', u'z2_top3', u'z2_top4', u'z2_top5', u'z3_top1', u'z3_top2', u'z3_top3', u'z3_top4', u'z3_top5', u'z4_top1', u'z4_top2', u'z4_top3', u'z4_top4', u'z4_top5', u'z5_top1', u'z5_top2', u'z5_top3', u'z5_top4', u'z5_top5', u'z6_top1', u'z6_top2', u'z6_top3', u'z6_top4', u'z6_top5', u'z7_top1', u'z7_top2', u'z7_top3', u'z7_top4', u'z7_top5', u'z8_top1', u'z8_top2', u'z8_top3', u'z8_top4', u'z8_top5', u'z9_top1', u'z9_top2', u'z9_top3', u'z9_top4', u'z9_top5', u'z10_top1', u'z10_top2', u'z10_top3', u'z10_top4', u'z10_top5', u'z11_top1', u'z11_top2', u'z11_top3', u'z11_top4', u'z11_top5', u'z12_top1', u'z12_top2', u'z12_top3', u'z12_top4', u'z12_top5', u'z1_mean', u'z2_mean', u'z3_mean', u'z4_mean', u'z5_mean', u'z6_mean', u'z7_mean', u'z8_mean', u'z9_mean', u'z10_mean', u'z11_mean', u'z12_mean'], dtype=object)

# %% [markdown]
# FLANN Matcher

# %%
# FLANN parameters
FLANN_INDEX_KDTREE = 0
index_params = dict(algorithm = FLANN_INDEX_KDTREE, trees = 5)
search_params = dict(checks=100)   # or pass empty dictionary

flann = cv2.FlannBasedMatcher(index_params, search_params)

# %%
# %%time
DISTANCE_TH = 300

for inst in flatten_inst_arary[:5]:
    for zwd, zwd_inst_list in zip([1, 4], zwd_inst_mat):
        prop_matched_list = []
        for zwd_inst in zwd_inst_list:
            # print(i)
            if zwd_inst.desc_list is None:
                # print("{} of zwd({}) has no features".format(zwd_inst.ix, zwd_inst.zwd))
                prop_matched_list.append(0)
                continue
            len_zwd_inst_features = len(zwd_inst.desc_list)
            all_matches = flann.knnMatch(
                inst.desc_list,
                zwd_inst.desc_list,
                k=len_zwd_inst_features
            )
            matches_mat = np.array([
                [m.distance for m in sorted(row, key=lambda x: x.trainIdx)]
                for row in all_matches
            ])
            prop_matched_list.append(
                np.sum(np.where(matches_mat < DISTANCE_TH, 1, 0).sum(axis=0) != 0) / float(len_zwd_inst_features)
            )
        
        # write match result to data fame
        prop_matched_list.sort(reverse=True)
        df_sift_train_out.ix[inst.ix, "z{}_top1".format(zwd):"z{}_top{}".format(zwd, TOP_K)] = prop_matched_list[:TOP_K]
        df_sift_train_out.ix[inst.ix, "z{}_mean".format(zwd)] = np.mean(prop_matched_list)
# Out:
# CPU times: user 10.9 s, sys: 2 ms, total: 10.9 s
# Wall time: 11 s

# %%
# %%time
DISTANCE_TH = 300

for inst in flatten_inst_arary[:5]:
    for zwd, zwd_inst_list in zip([1, 4], zwd_inst_mat):
        prop_matched_list = []
        for zwd_inst in zwd_inst_list:
            # print(i)
            if zwd_inst.desc_list is None:
                # print("{} of zwd({}) has no features".format(zwd_inst.ix, zwd_inst.zwd))
                prop_matched_list.append(0)
                continue
            len_feature = len(zwd_inst.desc_list)
            all_matches = flann.knnMatch(
                inst.desc_list,
                zwd_inst.desc_list,
                k=len_feature
            )
            matches_mat = np.unique([
                m.trainIdx for row in all_matches for m in row if m.distance < DISTANCE_TH
            ])
            prop_matched_list.append(
               len(matches_mat) / float(len_feature)
            )
        # write match result to data fame
        # prop_matched_list.sort(reverse=True)
        prop_matched_list = np.sort(prop_matched_list)[::-1]
        df_sift_train_out.ix[inst.ix, "z{}_top1".format(zwd):"z{}_top{}".format(zwd, TOP_K)] = prop_matched_list[:TOP_K]
        df_sift_train_out.ix[inst.ix, "z{}_mean".format(zwd)] = np.mean(prop_matched_list)
# Out:
# CPU times: user 5.84 s, sys: 0 ns, total: 5.84 s
# Wall time: 5.85 s

# %%
df_sift_train_out.ix[[1, 22, 33, 48, 52], :10]
# Out:
#     y  z1_top1   z1_top2   z1_top3   z1_top4   z1_top5  z2_top1  z2_top2  \
# 1   1        1  0.888889  0.740741  0.733333  0.714286        0        0
# 22  1        1  0.777778  0.777778  0.666667  0.666667        0        0
# 33  1        1  0.666667  0.613636  0.588235  0.578947        0        0
# 48  1        1  0.800000  0.705882  0.700000  0.681818        0        0
# 52  1        1  0.750000  0.720000  0.708333  0.697674        0        0
#
#     z2_top3  z2_top4
# 1         0        0
# 22        0        0
# 33        0        0
# 48        0        0
# 52        0        0

# %%
df_sift_train_out.ix[[1, 22, 33, 48, 52], :10]
# Out:
#     y  z1_top1   z1_top2   z1_top3   z1_top4   z1_top5  z2_top1  z2_top2  \
# 1   1        1  0.888889  0.740741  0.733333  0.714286        0        0
# 22  1        1  0.777778  0.777778  0.666667  0.666667        0        0
# 33  1        1  0.666667  0.613636  0.588235  0.578947        0        0
# 48  1        1  0.800000  0.705882  0.700000  0.681818        0        0
# 52  1        1  0.750000  0.720000  0.708333  0.697674        0        0
#
#     z2_top3  z2_top4
# 1         0        0
# 22        0        0
# 33        0        0
# 48        0        0
# 52        0        0

# %% [markdown]
# ### Speed up

# %%
# %%time
DISTANCE_TH = 250
map(zwd_whole_combine, flatten_inst_arary[:10])
# Out:
# CPU times: user 22.7 s, sys: 37.3 ms, total: 22.8 s
# Wall time: 22.8 s

# %%
CSV_SIFT_TRANSFORM = "dataset/train_60x60_grey_SIFT.csv"
df_sift_train_out.to_csv(CSV_SIFT_TRANSFORM, index=False)

# %%
mat = np.array([[1, 2, 4, 5], [1, 1, 5], []])

# %%
any(mat.ravel() == 1)
# Out:
# False

# %%
group_inst_ix[0][:5]
# Out:
# [1, 22, 33, 48, 52]

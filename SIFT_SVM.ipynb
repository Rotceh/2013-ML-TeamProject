# %%
from __future__ import print_function
import numpy as np
import pandas as pd
from sklearn import svm
from sklearn.cross_validation import cross_val_score, train_test_split
from sklearn.grid_search import GridSearchCV
from sklearn.metrics import classification_report, confusion_matrix

# %%
CSV_TRAIN = "dataset/train_60x60_grey_SIFT_top100_distth300.csv"
CSV_TEST = "dataset/test_60x60_grey_SIFT_top100_distth300.csv"
df_train = pd.read_csv(CSV_TRAIN)

# %%
CSV_TRAIN = "dataset/train_raw_grey_SIFT_top150_distth250.csv"
CSV_TEST = "dataset/test_raw_grey_SIFT_top150_distth250.csv"
df_train = pd.read_csv(CSV_TRAIN)

# %%
Y = df_train.y.values
X = df_train.iloc[:, 1:].values

# %% [markdown]
# ### Grid CV

# %%
GRID_RESULT = "results/grid_CV/svm_rawsift_0110_1.txt"

param_list = [
    {'C': [0.01, 0.1, 0.2, 0.5, 1, 2, 5, 10, 100, 500, 1000]},
    {'kernel': ['rbf'],
     'C': [0.01, 0.05, 0.1, 0.5,
           1, 10, 50, 100, 200, 500, 1000],
     'gamma': [0.1, 0.05, 0.02,
               0.01, 0.005, 0.002,
               0.001]}
]

linsvm_clf = svm.LinearSVC()
svm_clf = svm.SVC(cache_size=2000)  # Don't try this at home!

train_X, test_X, train_Y, test_Y = train_test_split(
    X, Y, test_size=0.25, random_state=5566
)

# %%
# %%capture out_cap
for clf, param in zip((linsvm_clf, svm_clf), param_list):
    grid_cv = GridSearchCV(clf, param, n_jobs=14, verbose=1)
    grid_cv.fit(train_X, train_Y)
    
    with open(GRID_RESULT, "a") as f:
        msg = (
            "\n\n>>>>> [best parameter from grid searching] <<<<<\n"
            "%s\n\n\n" % grid_cv.best_estimator_
        )
        print(msg)
        print(msg, file=f)
        
        for params, mean_score, scores in grid_cv.grid_scores_:
            row_msg = (
                "%0.3f (+/-%0.03f) for %r"
                % (mean_score, scores.std() / 2, params)
            )
            print(row_msg)
            print(msg, file=f)

    # best model to predict
    pred_Y = grid_cv.predict(test_X)
    
    # prediction report
    print(classification_report(test_Y, pred_Y))
    print(confusion_matrix(test_Y, pred_Y))

# %%
out_cap.show()
# Out:
# Fitting 3 folds for each of 11 candidates, totalling 33 fits
#
#
# >>>>> [best parameter from grid searching] <<<<<
# LinearSVC(C=0.5, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss=l2, multi_class=ovr, penalty=l2,
#      random_state=None, tol=0.0001, verbose=0)
#
#
#
# 0.461 (+/-0.005) for {'C': 0.01}
# 0.487 (+/-0.006) for {'C': 0.1}
# 0.488 (+/-0.005) for {'C': 0.2}
# 0.489 (+/-0.007) for {'C': 0.5}
# 0.478 (+/-0.008) for {'C': 1}
# 0.443 (+/-0.007) for {'C': 2}
# 0.410 (+/-0.011) for {'C': 5}
# 0.401 (+/-0.020) for {'C': 10}
# 0.362 (+/-0.020) for {'C': 100}
# 0.336 (+/-0.015) for {'C': 500}
# 0.322 (+/-0.011) for {'C': 1000}
#              precision    recall  f1-score   support
#
#         1.0       0.78      0.56      0.65       193
#         2.0       0.69      0.40      0.51       205
#         3.0       0.68      0.43      0.53       188
#         4.0       0.70      0.50      0.58       195
#         5.0       0.76      0.51      0.61       210
#         6.0       0.71      0.43      0.54       192
#         7.0       0.15      0.74      0.26       189
#         8.0       0.69      0.32      0.43       190
#         9.0       0.70      0.51      0.59       186
#        10.0       0.76      0.56      0.64       200
#        11.0       0.60      0.50      0.55       163
#        12.0       0.75      0.48      0.58       193
#
# avg / total       0.67      0.49      0.54      2304
#
# [[109   0   3  10   3   1  61   1   2   0   3   0]
#  [  0  83   2   3   0   3  78  17   6   5   3   5]
#  [  6   4  81   3   7   5  57   2   8   4   8   3]
#  [  4   1   4  97   4   6  65   0   4   2   8   0]
#  [  8   0   3   3 108   1  77   0   1   4   2   3]
#  [  2   1   1   2   4  83  79   1   4   4   9   2]
#  [  2   4  12   5   4   8 139   1   3   5   1   5]
#  [  0  22   5   2   2   3  79  60   6   4   2   5]
#  [  2   2   1   4   2   3  66   2  94   2   5   3]
#  [  2   1   0   5   2   1  72   3   0 111   2   1]
#  [  4   0   2   1   2   1  60   0   5   2  82   4]
#  [  1   2   5   4   4   2  66   0   1   4  12  92]]
# Fitting 3 folds for each of 77 candidates, totalling 231 fits
#
#
# >>>>> [best parameter from grid searching] <<<<<
# SVC(C=1000, cache_size=2000, class_weight=None, coef0=0.0, degree=3,
#   gamma=0.001, kernel=rbf, max_iter=-1, probability=False,
#   random_state=None, shrinking=True, tol=0.001, verbose=False)
#
#
#
# 0.087 (+/-0.000) for {'kernel': 'rbf', 'C': 0.01, 'gamma': 0.1}
# 0.087 (+/-0.000) for {'kernel': 'rbf', 'C': 0.01, 'gamma': 0.05}
# 0.087 (+/-0.000) for {'kernel': 'rbf', 'C': 0.01, 'gamma': 0.02}
# 0.087 (+/-0.000) for {'kernel': 'rbf', 'C': 0.01, 'gamma': 0.01}
# 0.087 (+/-0.000) for {'kernel': 'rbf', 'C': 0.01, 'gamma': 0.005}
# 0.087 (+/-0.000) for {'kernel': 'rbf', 'C': 0.01, 'gamma': 0.002}
# 0.087 (+/-0.000) for {'kernel': 'rbf', 'C': 0.01, 'gamma': 0.001}
# 0.110 (+/-0.001) for {'kernel': 'rbf', 'C': 0.05, 'gamma': 0.1}
# 0.098 (+/-0.002) for {'kernel': 'rbf', 'C': 0.05, 'gamma': 0.05}
# 0.090 (+/-0.000) for {'kernel': 'rbf', 'C': 0.05, 'gamma': 0.02}
# 0.088 (+/-0.001) for {'kernel': 'rbf', 'C': 0.05, 'gamma': 0.01}
# 0.087 (+/-0.000) for {'kernel': 'rbf', 'C': 0.05, 'gamma': 0.005}
# 0.089 (+/-0.001) for {'kernel': 'rbf', 'C': 0.05, 'gamma': 0.002}
# 0.087 (+/-0.000) for {'kernel': 'rbf', 'C': 0.05, 'gamma': 0.001}
# 0.145 (+/-0.001) for {'kernel': 'rbf', 'C': 0.1, 'gamma': 0.1}
# 0.120 (+/-0.002) for {'kernel': 'rbf', 'C': 0.1, 'gamma': 0.05}
# 0.101 (+/-0.003) for {'kernel': 'rbf', 'C': 0.1, 'gamma': 0.02}
# 0.097 (+/-0.003) for {'kernel': 'rbf', 'C': 0.1, 'gamma': 0.01}
# 0.091 (+/-0.003) for {'kernel': 'rbf', 'C': 0.1, 'gamma': 0.005}
# 0.088 (+/-0.002) for {'kernel': 'rbf', 'C': 0.1, 'gamma': 0.002}
# 0.086 (+/-0.001) for {'kernel': 'rbf', 'C': 0.1, 'gamma': 0.001}
# 0.350 (+/-0.004) for {'kernel': 'rbf', 'C': 0.5, 'gamma': 0.1}
# 0.299 (+/-0.003) for {'kernel': 'rbf', 'C': 0.5, 'gamma': 0.05}
# 0.202 (+/-0.004) for {'kernel': 'rbf', 'C': 0.5, 'gamma': 0.02}
# 0.154 (+/-0.008) for {'kernel': 'rbf', 'C': 0.5, 'gamma': 0.01}
# 0.118 (+/-0.001) for {'kernel': 'rbf', 'C': 0.5, 'gamma': 0.005}
# 0.094 (+/-0.001) for {'kernel': 'rbf', 'C': 0.5, 'gamma': 0.002}
# 0.090 (+/-0.001) for {'kernel': 'rbf', 'C': 0.5, 'gamma': 0.001}
# 0.420 (+/-0.002) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.1}
# 0.396 (+/-0.002) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.05}
# 0.323 (+/-0.004) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.02}
# 0.244 (+/-0.005) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.01}
# 0.169 (+/-0.008) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.005}
# 0.114 (+/-0.003) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.002}
# 0.093 (+/-0.001) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.001}
# 0.470 (+/-0.006) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.1}
# 0.471 (+/-0.006) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.05}
# 0.472 (+/-0.005) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.02}
# 0.464 (+/-0.004) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.01}
# 0.446 (+/-0.003) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.005}
# 0.386 (+/-0.005) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.002}
# 0.303 (+/-0.005) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.001}
# 0.456 (+/-0.004) for {'kernel': 'rbf', 'C': 50, 'gamma': 0.1}
# 0.467 (+/-0.005) for {'kernel': 'rbf', 'C': 50, 'gamma': 0.05}
# 0.478 (+/-0.006) for {'kernel': 'rbf', 'C': 50, 'gamma': 0.02}
# 0.481 (+/-0.004) for {'kernel': 'rbf', 'C': 50, 'gamma': 0.01}
# 0.481 (+/-0.006) for {'kernel': 'rbf', 'C': 50, 'gamma': 0.005}
# 0.468 (+/-0.004) for {'kernel': 'rbf', 'C': 50, 'gamma': 0.002}
# 0.447 (+/-0.003) for {'kernel': 'rbf', 'C': 50, 'gamma': 0.001}
# 0.455 (+/-0.004) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.1}
# 0.463 (+/-0.005) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.05}
# 0.475 (+/-0.006) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.02}
# 0.480 (+/-0.005) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.01}
# 0.482 (+/-0.004) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.005}
# 0.480 (+/-0.004) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.002}
# 0.471 (+/-0.004) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.001}
# 0.455 (+/-0.004) for {'kernel': 'rbf', 'C': 200, 'gamma': 0.1}
# 0.463 (+/-0.006) for {'kernel': 'rbf', 'C': 200, 'gamma': 0.05}
# 0.473 (+/-0.005) for {'kernel': 'rbf', 'C': 200, 'gamma': 0.02}
# 0.481 (+/-0.007) for {'kernel': 'rbf', 'C': 200, 'gamma': 0.01}
# 0.481 (+/-0.005) for {'kernel': 'rbf', 'C': 200, 'gamma': 0.005}
# 0.482 (+/-0.005) for {'kernel': 'rbf', 'C': 200, 'gamma': 0.002}
# 0.482 (+/-0.004) for {'kernel': 'rbf', 'C': 200, 'gamma': 0.001}
# 0.455 (+/-0.004) for {'kernel': 'rbf', 'C': 500, 'gamma': 0.1}
# 0.463 (+/-0.006) for {'kernel': 'rbf', 'C': 500, 'gamma': 0.05}
# 0.468 (+/-0.006) for {'kernel': 'rbf', 'C': 500, 'gamma': 0.02}
# 0.473 (+/-0.005) for {'kernel': 'rbf', 'C': 500, 'gamma': 0.01}
# 0.480 (+/-0.005) for {'kernel': 'rbf', 'C': 500, 'gamma': 0.005}
# 0.484 (+/-0.005) for {'kernel': 'rbf', 'C': 500, 'gamma': 0.002}
# 0.483 (+/-0.005) for {'kernel': 'rbf', 'C': 500, 'gamma': 0.001}
# 0.455 (+/-0.004) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.1}
# 0.463 (+/-0.006) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.05}
# 0.468 (+/-0.005) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.02}
# 0.469 (+/-0.005) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.01}
# 0.475 (+/-0.004) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.005}
# 0.478 (+/-0.004) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.002}
# 0.485 (+/-0.006) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.001}
#              precision    recall  f1-score   support
#
#         1.0       0.71      0.56      0.63       193
#         2.0       0.68      0.41      0.51       205
#         3.0       0.61      0.45      0.52       188
#         4.0       0.65      0.50      0.56       195
#         5.0       0.76      0.47      0.58       210
#         6.0       0.72      0.44      0.55       192
#         7.0       0.16      0.76      0.26       189
#         8.0       0.61      0.33      0.43       190
#         9.0       0.81      0.48      0.60       186
#        10.0       0.79      0.55      0.64       200
#        11.0       0.64      0.49      0.56       163
#        12.0       0.75      0.41      0.53       193
#
# avg / total       0.66      0.49      0.53      2304
#
# [[109   1   3  13   2   0  62   2   1   0   0   0]
#  [  0  84   6   1   0   4  78  20   2   3   3   4]
#  [ 10   2  85   4   6   4  58   4   3   3   6   3]
#  [  3   2   6  97   1   6  67   1   3   0   7   2]
#  [  7   0   5   2  99   3  78   2   3   4   3   4]
#  [  4   2   1   3   3  85  80   1   3   2   7   1]
#  [  6   2  12   6   3   3 144   2   0   5   2   4]
#  [  1  26   9   4   2   1  76  63   3   2   1   2]
#  [  2   2   3   5   3   2  65   3  89   3   5   4]
#  [  2   0   2   4   2   1  72   5   1 109   1   1]
#  [  7   0   3   2   3   2  60   1   1   2  80   2]
#  [  2   3   4   8   6   7  67   0   1   5  10  80]]
# [Parallel(n_jobs=14)]: Done   1 jobs       | elapsed:   40.0s
# [Parallel(n_jobs=14)]: Done   7 out of  33 | elapsed:  5.3min remaining: 19.8min
# [Parallel(n_jobs=14)]: Done  33 out of  33 | elapsed: 15.1min finished
# [Parallel(n_jobs=14)]: Done   1 jobs       | elapsed:  4.6min
# [Parallel(n_jobs=14)]: Done  50 jobs       | elapsed: 27.1min
# [Parallel(n_jobs=14)]: Done 200 jobs       | elapsed: 78.3min
# [Parallel(n_jobs=14)]: Done 205 out of 231 | elapsed: 79.8min remaining: 10.1min
# [Parallel(n_jobs=14)]: Done 231 out of 231 | elapsed: 85.1min finished

# %% [markdown]
# cannot separate y=7(馬)

# %% [markdown]
# ## Work on original dataset

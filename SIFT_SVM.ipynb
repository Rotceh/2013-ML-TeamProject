# %%
from __future__ import print_function
import numpy as np
import pandas as pd
from sklearn import svm
from sklearn.cross_validation import cross_val_score, train_test_split
from sklearn.grid_search import GridSearchCV
from sklearn.metrics import classification_report, confusion_matrix

# %%
CSV_TRAIN = "dataset/train_60x60_grey_SIFT_top150_distth350.csv"
CSV_TEST = "dataset/test_60x60_grey_SIFT_top150_distth350.csv"
df_train = pd.read_csv(CSV_TRAIN)

# %%
CSV_TRAIN = "dataset/train_60x60_grey_SIFT_top150_distth300.csv"
CSV_TEST = "dataset/test_60x60_grey_SIFT_top150_distth300.csv"
df_train = pd.read_csv(CSV_TRAIN)

# %%
CSV_TRAIN = "dataset/train_raw_grey_SIFT_top150_distth350.csv"
CSV_TEST = "dataset/test_raw_grey_SIFT_top150_distth350.csv"
df_train = pd.read_csv(CSV_TRAIN)

# %%
Y = df_train.y.values
X = df_train.iloc[:, 1:].values

# %%
CSV_TEST
# Out:
# 'dataset/test_raw_grey_SIFT_top150_distth350.csv'

# %% [markdown]
# ### Grid CV

# %%
GRID_RESULT = "results/grid_CV/svm_rawsift_th350_0112_1.txt"

param_list = [
    {'C': [0.01, 0.1, 0.2, 0.5, 1, 2, 5, 10, 100, 500, 1000]},
    {'kernel': ['rbf'],
     'C': [0.01, 0.05, 0.1, 0.5,
           1, 10, 50, 100, 200, 500, 1000],
     'gamma': [0.1, 0.05, 0.02,
               0.01, 0.005, 0.002,
               0.001]}
]

linsvm_clf = svm.LinearSVC()
svm_clf = svm.SVC(cache_size=2000)  # Don't try this at home!

train_X, test_X, train_Y, test_Y = train_test_split(
    X, Y, test_size=0.25, random_state=5566
)

# %%
# %%capture out_cap
for clf, param in zip((linsvm_clf, svm_clf), param_list):
    grid_cv = GridSearchCV(clf, param, n_jobs=12, verbose=1)
    grid_cv.fit(train_X, train_Y)
    
    with open(GRID_RESULT, "a") as f:
        msg = (
            "\n\n>>>>> [best parameter from grid searching] <<<<<\n"
            "%s\n\n\n" % grid_cv.best_estimator_
        )
        print(msg)
        print(msg, file=f)
        
        for params, mean_score, scores in grid_cv.grid_scores_:
            row_msg = (
                "%0.3f (+/-%0.03f) for %r"
                % (mean_score, scores.std() / 2, params)
            )
            print(row_msg)
            print(msg, file=f)

    # best model to predict
    pred_Y = grid_cv.predict(test_X)
    
    # prediction report
    print(classification_report(test_Y, pred_Y))
    print(confusion_matrix(test_Y, pred_Y))

# %%
out_cap.show()
# Out:
# Fitting 3 folds for each of 11 candidates, totalling 33 fits
#
#
# >>>>> [best parameter from grid searching] <<<<<
# LinearSVC(C=0.2, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss=l2, multi_class=ovr, penalty=l2,
#      random_state=None, tol=0.0001, verbose=0)
#
#
#
# 0.402 (+/-0.003) for {'C': 0.01}
# 0.450 (+/-0.004) for {'C': 0.1}
# 0.452 (+/-0.005) for {'C': 0.2}
# 0.447 (+/-0.005) for {'C': 0.5}
# 0.418 (+/-0.010) for {'C': 1}
# 0.393 (+/-0.020) for {'C': 2}
# 0.369 (+/-0.023) for {'C': 5}
# 0.302 (+/-0.026) for {'C': 10}
# 0.269 (+/-0.010) for {'C': 100}
# 0.291 (+/-0.007) for {'C': 500}
# 0.297 (+/-0.013) for {'C': 1000}
#              precision    recall  f1-score   support
#
#         1.0       0.76      0.55      0.64       193
#         2.0       0.61      0.40      0.49       205
#         3.0       0.55      0.31      0.40       188
#         4.0       0.57      0.36      0.44       195
#         5.0       0.73      0.52      0.61       210
#         6.0       0.60      0.35      0.44       192
#         7.0       0.15      0.70      0.25       189
#         8.0       0.63      0.33      0.43       190
#         9.0       0.60      0.41      0.49       186
#        10.0       0.65      0.52      0.58       200
#        11.0       0.54      0.43      0.48       163
#        12.0       0.68      0.46      0.54       193
#
# avg / total       0.59      0.45      0.48      2304
#
# [[106   0   2   4   8   2  62   2   2   3   2   0]
#  [  1  83   1   2   0   2  79  21   7   4   3   2]
#  [  8   5  58   8   5   7  58   4   5   9  14   7]
#  [  5   3  10  70   5   8  67   1   6   6  10   4]
#  [  5   2   3   1 110   1  76   0   1   3   2   6]
#  [  5   3   5   9   3  67  79   0   7   3   9   2]
#  [  1   4   7   6   5   8 133   2   9   5   6   3]
#  [  1  23   7   4   2   2  74  62   6   7   0   2]
#  [  3   5   1  10   5   2  67   2  76   7   4   4]
#  [  3   1   3   2   2   0  73   2   2 104   3   5]
#  [  2   2   2   2   1  11  61   1   2   2  70   7]
#  [  0   6   6   4   5   1  64   2   4   6   7  88]]
# Fitting 3 folds for each of 77 candidates, totalling 231 fits
#
#
# >>>>> [best parameter from grid searching] <<<<<
# SVC(C=500, cache_size=2000, class_weight=None, coef0=0.0, degree=3,
#   gamma=0.001, kernel=rbf, max_iter=-1, probability=False,
#   random_state=None, shrinking=True, tol=0.001, verbose=False)
#
#
#
# 0.087 (+/-0.000) for {'kernel': 'rbf', 'C': 0.01, 'gamma': 0.1}
# 0.087 (+/-0.000) for {'kernel': 'rbf', 'C': 0.01, 'gamma': 0.05}
# 0.087 (+/-0.000) for {'kernel': 'rbf', 'C': 0.01, 'gamma': 0.02}
# 0.087 (+/-0.000) for {'kernel': 'rbf', 'C': 0.01, 'gamma': 0.01}
# 0.087 (+/-0.000) for {'kernel': 'rbf', 'C': 0.01, 'gamma': 0.005}
# 0.087 (+/-0.000) for {'kernel': 'rbf', 'C': 0.01, 'gamma': 0.002}
# 0.087 (+/-0.000) for {'kernel': 'rbf', 'C': 0.01, 'gamma': 0.001}
# 0.117 (+/-0.001) for {'kernel': 'rbf', 'C': 0.05, 'gamma': 0.1}
# 0.108 (+/-0.001) for {'kernel': 'rbf', 'C': 0.05, 'gamma': 0.05}
# 0.094 (+/-0.005) for {'kernel': 'rbf', 'C': 0.05, 'gamma': 0.02}
# 0.092 (+/-0.004) for {'kernel': 'rbf', 'C': 0.05, 'gamma': 0.01}
# 0.092 (+/-0.002) for {'kernel': 'rbf', 'C': 0.05, 'gamma': 0.005}
# 0.089 (+/-0.001) for {'kernel': 'rbf', 'C': 0.05, 'gamma': 0.002}
# 0.088 (+/-0.001) for {'kernel': 'rbf', 'C': 0.05, 'gamma': 0.001}
# 0.150 (+/-0.001) for {'kernel': 'rbf', 'C': 0.1, 'gamma': 0.1}
# 0.140 (+/-0.000) for {'kernel': 'rbf', 'C': 0.1, 'gamma': 0.05}
# 0.120 (+/-0.003) for {'kernel': 'rbf', 'C': 0.1, 'gamma': 0.02}
# 0.100 (+/-0.002) for {'kernel': 'rbf', 'C': 0.1, 'gamma': 0.01}
# 0.091 (+/-0.002) for {'kernel': 'rbf', 'C': 0.1, 'gamma': 0.005}
# 0.088 (+/-0.001) for {'kernel': 'rbf', 'C': 0.1, 'gamma': 0.002}
# 0.090 (+/-0.001) for {'kernel': 'rbf', 'C': 0.1, 'gamma': 0.001}
# 0.259 (+/-0.001) for {'kernel': 'rbf', 'C': 0.5, 'gamma': 0.1}
# 0.219 (+/-0.003) for {'kernel': 'rbf', 'C': 0.5, 'gamma': 0.05}
# 0.180 (+/-0.005) for {'kernel': 'rbf', 'C': 0.5, 'gamma': 0.02}
# 0.153 (+/-0.001) for {'kernel': 'rbf', 'C': 0.5, 'gamma': 0.01}
# 0.127 (+/-0.002) for {'kernel': 'rbf', 'C': 0.5, 'gamma': 0.005}
# 0.101 (+/-0.003) for {'kernel': 'rbf', 'C': 0.5, 'gamma': 0.002}
# 0.092 (+/-0.002) for {'kernel': 'rbf', 'C': 0.5, 'gamma': 0.001}
# 0.331 (+/-0.003) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.1}
# 0.302 (+/-0.005) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.05}
# 0.243 (+/-0.005) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.02}
# 0.200 (+/-0.004) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.01}
# 0.157 (+/-0.004) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.005}
# 0.120 (+/-0.002) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.002}
# 0.101 (+/-0.002) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.001}
# 0.413 (+/-0.003) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.1}
# 0.420 (+/-0.004) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.05}
# 0.421 (+/-0.005) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.02}
# 0.405 (+/-0.006) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.01}
# 0.374 (+/-0.004) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.005}
# 0.315 (+/-0.004) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.002}
# 0.248 (+/-0.003) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.001}
# 0.402 (+/-0.004) for {'kernel': 'rbf', 'C': 50, 'gamma': 0.1}
# 0.416 (+/-0.004) for {'kernel': 'rbf', 'C': 50, 'gamma': 0.05}
# 0.433 (+/-0.005) for {'kernel': 'rbf', 'C': 50, 'gamma': 0.02}
# 0.440 (+/-0.004) for {'kernel': 'rbf', 'C': 50, 'gamma': 0.01}
# 0.435 (+/-0.006) for {'kernel': 'rbf', 'C': 50, 'gamma': 0.005}
# 0.418 (+/-0.006) for {'kernel': 'rbf', 'C': 50, 'gamma': 0.002}
# 0.385 (+/-0.005) for {'kernel': 'rbf', 'C': 50, 'gamma': 0.001}
# 0.399 (+/-0.004) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.1}
# 0.407 (+/-0.006) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.05}
# 0.430 (+/-0.005) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.02}
# 0.439 (+/-0.005) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.01}
# 0.443 (+/-0.005) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.005}
# 0.436 (+/-0.005) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.002}
# 0.416 (+/-0.005) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.001}
# 0.399 (+/-0.004) for {'kernel': 'rbf', 'C': 200, 'gamma': 0.1}
# 0.403 (+/-0.006) for {'kernel': 'rbf', 'C': 200, 'gamma': 0.05}
# 0.421 (+/-0.007) for {'kernel': 'rbf', 'C': 200, 'gamma': 0.02}
# 0.436 (+/-0.005) for {'kernel': 'rbf', 'C': 200, 'gamma': 0.01}
# 0.443 (+/-0.004) for {'kernel': 'rbf', 'C': 200, 'gamma': 0.005}
# 0.443 (+/-0.006) for {'kernel': 'rbf', 'C': 200, 'gamma': 0.002}
# 0.434 (+/-0.004) for {'kernel': 'rbf', 'C': 200, 'gamma': 0.001}
# 0.399 (+/-0.004) for {'kernel': 'rbf', 'C': 500, 'gamma': 0.1}
# 0.403 (+/-0.006) for {'kernel': 'rbf', 'C': 500, 'gamma': 0.05}
# 0.414 (+/-0.003) for {'kernel': 'rbf', 'C': 500, 'gamma': 0.02}
# 0.425 (+/-0.007) for {'kernel': 'rbf', 'C': 500, 'gamma': 0.01}
# 0.433 (+/-0.004) for {'kernel': 'rbf', 'C': 500, 'gamma': 0.005}
# 0.445 (+/-0.006) for {'kernel': 'rbf', 'C': 500, 'gamma': 0.002}
# 0.445 (+/-0.005) for {'kernel': 'rbf', 'C': 500, 'gamma': 0.001}
# 0.399 (+/-0.004) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.1}
# 0.403 (+/-0.006) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.05}
# 0.413 (+/-0.004) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.02}
# 0.415 (+/-0.005) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.01}
# 0.427 (+/-0.005) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.005}
# 0.437 (+/-0.004) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.002}
# 0.445 (+/-0.006) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.001}
#              precision    recall  f1-score   support
#
#         1.0       0.76      0.53      0.63       193
#         2.0       0.61      0.41      0.49       205
#         3.0       0.50      0.43      0.46       188
#         4.0       0.60      0.36      0.45       195
#         5.0       0.74      0.51      0.60       210
#         6.0       0.59      0.36      0.45       192
#         7.0       0.14      0.68      0.24       189
#         8.0       0.57      0.34      0.42       190
#         9.0       0.62      0.42      0.50       186
#        10.0       0.75      0.47      0.58       200
#        11.0       0.55      0.40      0.46       163
#        12.0       0.70      0.40      0.51       193
#
# avg / total       0.60      0.44      0.49      2304
#
# [[103   0   3   7   8   3  63   2   1   0   1   2]
#  [  0  85   5   1   1   1  80  21   4   1   3   3]
#  [  4   5  80   9   4   5  55   5   4   4  11   2]
#  [  8   2  14  71   2   8  68   2   7   2   8   3]
#  [  5   1   5   2 107   3  77   0   0   3   2   5]
#  [  3   1   7   6   4  70  78   0   8   3  10   2]
#  [  4   6  17   4   3   7 128   4   8   3   1   4]
#  [  0  23   6   3   2   2  78  64   6   2   0   4]
#  [  3   5   1   5   3   4  68   4  79   6   7   1]
#  [  4   2   7   2   2   1  75   3   4  95   1   4]
#  [  0   4   7   4   2  10  57   2   4   5  65   3]
#  [  1   6   9   4   7   4  64   5   3   3   9  78]]
# [Parallel(n_jobs=8)]: Done   1 jobs       | elapsed:  1.1min
# [Parallel(n_jobs=8)]: Done  33 out of  33 | elapsed: 29.1min finished
# [Parallel(n_jobs=8)]: Done   1 jobs       | elapsed:  5.3min
# [Parallel(n_jobs=8)]: Done  50 jobs       | elapsed: 38.3min
# [Parallel(n_jobs=8)]: Done 200 jobs       | elapsed: 127.2min
# [Parallel(n_jobs=8)]: Done 217 out of 231 | elapsed: 135.1min remaining:  8.7min
# [Parallel(n_jobs=8)]: Done 231 out of 231 | elapsed: 140.0min finished

# %% [markdown]
# cannot separate y=7(馬)

# %% [markdown]
# ## Work on original dataset

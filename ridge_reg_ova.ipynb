# %% [markdown]
# # Ridge Regression using OVA

# %% [markdown]
# 預計要做的事情：
#
# - ridge regression [ ]
# - OVA [ ]
# - Parallel using IPython Cluster [ ]

# %%
import pandas as pd
import numpy as np

# %%
CSV_ZERO_TRAIN = "dataset/train_na2zero.csv"

# %% [markdown]
# 第一次建議先用一部份的資料來跑…

# %%
df = pd.read_csv(CSV_ZERO_TRAIN, nrows=1000)
# df = pd.read_csv(CSV_ZERO_TRAIN)

# %%
# 第一行是 Y
df.ix[:10, [0] + list(range(5000, 5010))]
# Out:
#      y    x_5000    x_5001    x_5002    x_5003    x_5004  x_5005    x_5006  \
# 0    2  0.000000  0.000000  0.000000  0.000000  0.000000       0  0.000000
# 1    1  0.000000  0.000000  0.000000  0.000000  0.000000       0  0.000000
# 2    9  0.007843  0.003922  0.003922  0.003922  0.003922       0  0.000000
# 3   10  0.000000  0.000000  0.000000  0.000000  0.000000       0  0.000000
# 4    9  0.000000  0.000000  0.011765  0.000000  0.372549       1  0.239216
# 5    6  0.000000  0.000000  0.000000  0.000000  0.000000       0  0.000000
# 6   11  0.003922  0.003922  0.000000  0.000000  0.000000       0  0.000000
# 7    9  0.000000  0.000000  0.000000  0.000000  0.000000       0  0.000000
# 8    3  0.000000  0.000000  0.000000  0.000000  0.000000       0  0.000000
# 9    7  0.000000  0.000000  0.000000  0.000000  0.000000       0  0.000000
# 10   8  0.000000  0.000000  0.000000  0.000000  0.000000       0  0.000000
#
#       x_5007  x_5008    x_5009
# 0   0.000000       0  0.000000
# ...
